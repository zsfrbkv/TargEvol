# %% [markdown]
# # Chi-square association test

# %% [markdown]
# *Pearson's chi-squared test* is used as a test of independence. It assesses whether observations consisting of measures on two variables, expressed in a contingency table, are independent of each other (e.g. polling responses from people of different nationalities to see if one's nationality is related to the response). A p-value of less than or equal to a critical point is interpreted as justification for rejecting the null hypothesis that the row variable is independent of the column variable. The alternative hypothesis corresponds to the variables having an association or relationship where the structure of this relationship is not specified.
#
# More info: https://en.wikipedia.org/wiki/Pearson%27s_chi-squared_test#Testing_for_statistical_independence

# %% [markdown]
# Import dependencies and data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
# %matplotlib inline

# %%
data = pd.read_csv("../results/dnds_for_targets.csv", index_col=0)
print(data.shape)
data.head()
# Out:
# (14907, 9)
#   Gene name                                   Gene description  \
# 0   MT-ATP8  mitochondrially encoded ATP synthase membrane ...
# 1    MT-ND6  mitochondrially encoded NADH:ubiquinone oxidor...
# 2     KLF13  Kruppel like factor 13 [Source:HGNC Symbol;Acc...
# 3    KCNE1B  potassium voltage-gated channel subfamily E re...
# 4      PDK3  pyruvate dehydrogenase kinase 3 [Source:HGNC S...
#
#    dN with Chimpanzee  dS with Chimpanzee  dN/dS with Chimpanzee  \
# 0              0.0325              0.3331                 0.0976
# 1              0.0204              0.6559                 0.0311
# 2              0.0026              0.0771                 0.0337
# 3              0.0165              0.0649                 0.2542
# 4              0.0152              0.0300                 0.5067
#
#    dN with Mouse  dS with Mouse  dN/dS with Mouse  present in DrugBank
# 0         0.4871         0.8480            0.5744                False
# ...

# %%
data_filtered = data.dropna()
print(data_filtered.shape)
data_filtered.head()
# Out:
# (11882, 9)
#   Gene name                                   Gene description  \
# 0   MT-ATP8  mitochondrially encoded ATP synthase membrane ...
# 1    MT-ND6  mitochondrially encoded NADH:ubiquinone oxidor...
# 2     KLF13  Kruppel like factor 13 [Source:HGNC Symbol;Acc...
# 3    KCNE1B  potassium voltage-gated channel subfamily E re...
# 4      PDK3  pyruvate dehydrogenase kinase 3 [Source:HGNC S...
#
#    dN with Chimpanzee  dS with Chimpanzee  dN/dS with Chimpanzee  \
# 0              0.0325              0.3331                 0.0976
# 1              0.0204              0.6559                 0.0311
# 2              0.0026              0.0771                 0.0337
# 3              0.0165              0.0649                 0.2542
# 4              0.0152              0.0300                 0.5067
#
#    dN with Mouse  dS with Mouse  dN/dS with Mouse  present in DrugBank
# 0         0.4871         0.8480            0.5744                False
# ...

# %% [markdown]
# This function takes 2 rows of a contigency table and prints Chi2 test p-value:

# %%
def chi2_test(cont_table):
    
    stat, p, dof, expected = chi2_contingency(cont_table)
    print('significance=0.05, p={}'.format(p))

    if p <= 0.05: 
        print('dN & "goodness as a target" are dependent')
    else: 
        print('dN & "goodness as a target" are independent')
        
    return

# %% [markdown]
# ## Comparison of dN with the species average

# %%
# for chimpanzee vs human
mean_out=data_filtered[(data_filtered["present in DrugBank"] == False)]["dN with Chimpanzee"].mean()
mean_in=data_filtered[(data_filtered["present in DrugBank"] == True)]["dN with Chimpanzee"].mean()
mean_dN = np.mean(data_filtered["dN with Chimpanzee"])

sns.set(style="white", font_scale=1.3)
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(14, 6),)

sns.distplot(data_filtered[data_filtered["dN with Chimpanzee"] < 0.05]["dN with Chimpanzee"] , color="#010101", kde=True, ax=ax1)

sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == False) & (data_filtered["dN with Chimpanzee"] < 0.05)]["dN with Chimpanzee"] , color="#f03b20", shade=True, label="not in drugbank", ax=ax2)
sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == True) & (data_filtered["dN with Chimpanzee"] < 0.05)]["dN with Chimpanzee"] , color="#756bb1", shade=True, label="in drugbank", ax=ax2)

ax1.axvline(mean_dN, 0, 0.09, color="#000000").set_linestyle("-")
ax2.axvline(mean_in, 0, 0.14, color="#756bb1").set_linestyle("-")
ax2.axvline(mean_out, 0, 0.125, color="#f03b20").set_linestyle("-")

ax2.legend(loc="upper right")

ax1.set_title('dN distribution, all genes, Chimpanzee (all)')
ax2.set_title('dN distribution, by target groups, Chimpanzee (all)')
ax1.set_xlabel('')
ax2.set_xlabel("dN")
ax1.set_ylabel('density')
ax2.set_ylabel('density')

plt.xlim(0,0.05)
plt.show();

bad_targets = [data_filtered[(data_filtered["dN with Chimpanzee"] < mean_dN) & (data_filtered["present in DrugBank"] == False)].shape[0], 
               data_filtered[(data_filtered["dN with Chimpanzee"] >= mean_dN) & (data_filtered["present in DrugBank"] == False)].shape[0]]
good_targets = [data_filtered[(data_filtered["dN with Chimpanzee"] < mean_dN) & (data_filtered["present in DrugBank"] == True)].shape[0], 
               data_filtered[(data_filtered["dN with Chimpanzee"] >= mean_dN) & (data_filtered["present in DrugBank"] == True)].shape[0]]

print('-----------------------------------')
print('Results of Chi2 test for Chimpanzee')
print('-----------------------------------')
print('The contingency table looks like that:')
print(pd.DataFrame([bad_targets, good_targets],
                  index=['bad targets', 'good targets'],
                  columns=['dN < average dN', 'dN ≥ average dN']))
print()
print('Average dN is {}'.format(mean_dN))
chi2_test([bad_targets, good_targets])
print()
# Out:
# -----------------------------------
# Results of Chi2 test for Chimpanzee
# -----------------------------------
# The contingency table looks like that:
#               dN < average dN  dN ≥ average dN
# bad targets              8480             1951
# good targets             1208              243
#
# Average dN is 0.010855344218145095
# significance=0.05, p=0.07776484162231632
# dN & "goodness as a target" are independent

# %%
# for mouse vs human
mean_out=data_filtered[(data_filtered["present in DrugBank"] == False)]["dN with Mouse"].mean()
mean_in=data_filtered[(data_filtered["present in DrugBank"] == True)]["dN with Mouse"].mean()
mean_dN = np.mean(data_filtered["dN with Mouse"])

sns.set(style="white", font_scale=1.3)
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(14, 6),)

sns.distplot(data_filtered[data_filtered["dN with Mouse"] < 0.5]["dN with Mouse"] , color="#010101", kde=True, ax=ax1)

sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == False) & (data_filtered["dN with Mouse"] < 0.5)]["dN with Mouse"] , color="#f03b20", shade=True, label="not in drugbank", ax=ax2)
sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == True) & (data_filtered["dN with Mouse"] < 0.5)]["dN with Mouse"] , color="#756bb1", shade=True, label="in drugbank", ax=ax2)

ax1.axvline(mean_dN, 0, 0.5, color="#000000").set_linestyle("-")
ax2.axvline(mean_in, 0, 0.61, color="#756bb1").set_linestyle("-")
ax2.axvline(mean_out, 0, 0.45, color="#f03b20").set_linestyle("-")

ax2.legend(loc="upper right")

ax1.set_title('dN distribution, all genes, Mouse (all)')
ax2.set_title('dN distribution, by target groups, Mouse (all)')
ax1.set_xlabel('')
ax2.set_xlabel("dN")
ax1.set_ylabel('density')
ax2.set_ylabel('density')

plt.xlim(0,0.5)
plt.show();

bad_targets = [data_filtered[(data_filtered["dN with Mouse"] < mean_dN) & (data_filtered["present in DrugBank"] == False)].shape[0], 
               data_filtered[(data_filtered["dN with Mouse"] >= mean_dN) & (data_filtered["present in DrugBank"] == False)].shape[0]]
good_targets = [data_filtered[(data_filtered["dN with Mouse"] < mean_dN) & (data_filtered["present in DrugBank"] == True)].shape[0], 
               data_filtered[(data_filtered["dN with Mouse"] >= mean_dN) & (data_filtered["present in DrugBank"] == True)].shape[0]]

print('------------------------------')
print('Results of Chi2 test for Mouse')
print('------------------------------')
print('The contingency table looks like that:')
print(pd.DataFrame([bad_targets, good_targets],
                  index=['bad targets', 'good targets'],
                  columns=['dN < average dN', 'dN ≥ average dN']))
print()
print('Average dN is {}'.format(mean_dN))
chi2_test([bad_targets, good_targets])
# Out:
# ------------------------------
# Results of Chi2 test for Mouse
# ------------------------------
# The contingency table looks like that:
#               dN < average dN  dN ≥ average dN
# bad targets              6552             3879
# good targets             1080              371
#
# Average dN is 0.10956724457162095
# significance=0.05, p=6.572609094177726e-18
# dN & "goodness as a target" are dependent

# %% [markdown]
# ## Comparison of dN with the species median

# %%
# for chimpanzee vs human
median_dN = np.median(data_filtered["dN with Chimpanzee"])
median_out=data_filtered[(data_filtered["present in DrugBank"] == False)]["dN with Chimpanzee"].median()
median_in=data_filtered[(data_filtered["present in DrugBank"] == True)]["dN with Chimpanzee"].median()

sns.set(style="white", font_scale=1.3)
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(14, 6),)

sns.distplot(data_filtered[data_filtered["dN with Chimpanzee"] < 0.05]["dN with Chimpanzee"] , color="#010101", kde=True, ax=ax1)

sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == False) & (data_filtered["dN with Chimpanzee"] < 0.05)]["dN with Chimpanzee"] , color="#f03b20", shade=True, label="not in drugbank", ax=ax2)
sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == True) & (data_filtered["dN with Chimpanzee"] < 0.05)]["dN with Chimpanzee"] , color="#756bb1", shade=True, label="in drugbank", ax=ax2)

ax1.axvline(median_dN, 0, 0.56, color="#000000").set_linestyle("-")
ax2.axvline(median_in, 0, 0.8, color="#756bb1").set_linestyle("-")
ax2.axvline(median_out, 0, 0.74, color="#f03b20").set_linestyle("-")

ax2.legend(loc="upper right")

ax1.set_title('dN distribution, all genes, Chimpanzee (all)')
ax2.set_title('dN distribution, by target groups, Chimpanzee (all)')
ax1.set_xlabel('')
ax2.set_xlabel("dN")
ax1.set_ylabel('density')
ax2.set_ylabel('density')

plt.xlim(0,0.05)
plt.show();

bad_targets = [data_filtered[(data_filtered["dN with Chimpanzee"] < median_dN) & (data_filtered["present in DrugBank"] == False)].shape[0], 
               data_filtered[(data_filtered["dN with Chimpanzee"] >= median_dN) & (data_filtered["present in DrugBank"] == False)].shape[0]]
good_targets = [data_filtered[(data_filtered["dN with Chimpanzee"] < median_dN) & (data_filtered["present in DrugBank"] == True)].shape[0], 
               data_filtered[(data_filtered["dN with Chimpanzee"] >= median_dN) & (data_filtered["present in DrugBank"] == True)].shape[0]]

print('-----------------------------------')
print('Results of Chi2 test for Chimpanzee')
print('-----------------------------------')
print('The contingency table looks like that:')
print(pd.DataFrame([bad_targets, good_targets],
                  index=['bad targets', 'good targets'],
                  columns=['dN < median dN', 'dN ≥ median dN']))
print()
print('Median dN is {}'.format(median_dN))
chi2_test([bad_targets, good_targets])
print()
# Out:
# -----------------------------------
# Results of Chi2 test for Chimpanzee
# -----------------------------------
# The contingency table looks like that:
#               dN < median dN  dN ≥ median dN
# bad targets             5057            5374
# good targets             806             645
#
# Median dN is 0.0039
# significance=0.05, p=5.243238615977539e-07
# dN & "goodness as a target" are dependent

# %%
# for mouse vs human
median_dN = np.median(data_filtered["dN with Mouse"])
median_out=data_filtered[(data_filtered["present in DrugBank"] == False)]["dN with Mouse"].median()
median_in=data_filtered[(data_filtered["present in DrugBank"] == True)]["dN with Mouse"].median()

sns.set(style="white", font_scale=1.3)
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(14, 6),)

sns.distplot(data_filtered[data_filtered["dN with Mouse"] < 0.5]["dN with Mouse"] , color="#010101", kde=True, ax=ax1)

sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == False) & (data_filtered["dN with Mouse"] < 0.5)]["dN with Mouse"] , color="#f03b20", shade=True, label="not in drugbank", ax=ax2)
sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == True) & (data_filtered["dN with Mouse"] < 0.5)]["dN with Mouse"] , color="#756bb1", shade=True, label="in drugbank", ax=ax2)

ax1.axvline(median_dN, 0, 0.67, color="#000000").set_linestyle("-")
ax2.axvline(median_in, 0, 0.74, color="#756bb1").set_linestyle("-")
ax2.axvline(median_out, 0, 0.6, color="#f03b20").set_linestyle("-")

ax2.legend(loc="upper right")

ax1.set_title('dN distribution, all genes, Mouse (all)')
ax2.set_title('dN distribution, by target groups, Mouse (all)')
ax1.set_xlabel('')
ax2.set_xlabel("dN")
ax1.set_ylabel('density')
ax2.set_ylabel('density')

plt.xlim(0,0.5)
plt.show();

bad_targets = [data_filtered[(data_filtered["dN with Mouse"] < median_dN) & (data_filtered["present in DrugBank"] == False)].shape[0], 
               data_filtered[(data_filtered["dN with Mouse"] >= median_dN) & (data_filtered["present in DrugBank"] == False)].shape[0]]
good_targets = [data_filtered[(data_filtered["dN with Mouse"] < median_dN) & (data_filtered["present in DrugBank"] == True)].shape[0], 
               data_filtered[(data_filtered["dN with Mouse"] >= median_dN) & (data_filtered["present in DrugBank"] == True)].shape[0]]

print('------------------------------')
print('Results of Chi2 test for Mouse')
print('------------------------------')
print('The contingency table looks like that:')
print(pd.DataFrame([bad_targets, good_targets],
                  index=['bad targets', 'good targets'],
                  columns=['dN < median dN', 'dN ≥ median dN']))
print()
print('Median dN is {}'.format(median_dN))
chi2_test([bad_targets, good_targets])
# Out:
# ------------------------------
# Results of Chi2 test for Mouse
# ------------------------------
# The contingency table looks like that:
#               dN < median dN  dN ≥ median dN
# bad targets             5074            5357
# good targets             859             592
#
# Median dN is 0.0796
# significance=0.05, p=6.016227584499912e-14
# dN & "goodness as a target" are dependent

# %% [markdown]
# ## Comparison of dN with the 95% quantile

# %%
# for chimpanzee vs human
quantile_95_dN = np.quantile(data_filtered["dN with Chimpanzee"], 0.95)
quantile_95_out=np.quantile(data_filtered[(data_filtered["present in DrugBank"] == False)]["dN with Chimpanzee"], 0.95)
quantile_95_in=np.quantile(data_filtered[(data_filtered["present in DrugBank"] == True)]["dN with Chimpanzee"], 0.95)

sns.set(style="white", font_scale=1.3)
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(14, 6),)

sns.distplot(data_filtered[data_filtered["dN with Chimpanzee"] < 0.05]["dN with Chimpanzee"] , color="#010101", kde=True, ax=ax1)

sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == False) & (data_filtered["dN with Chimpanzee"] < 0.05)]["dN with Chimpanzee"] , color="#f03b20", shade=True, label="not in drugbank", ax=ax2)
sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == True) & (data_filtered["dN with Chimpanzee"] < 0.05)]["dN with Chimpanzee"] , color="#756bb1", shade=True, label="in drugbank", ax=ax2)

ax1.axvline(quantile_95_dN, 0, 0.01, color="#000000").set_linestyle("-")
ax2.axvline(quantile_95_in, 0, 0.03, color="#756bb1").set_linestyle("-")
ax2.axvline(quantile_95_out, 0, 0.01, color="#f03b20").set_linestyle("-")

ax2.legend(loc="upper right")

ax1.set_title('dN distribution, all genes, Chimpanzee (all)')
ax2.set_title('dN distribution, by target groups, Chimpanzee (all)')
ax1.set_xlabel('')
ax2.set_xlabel("dN")
ax1.set_ylabel('density')
ax2.set_ylabel('density')

plt.xlim(0,0.05)
plt.show();

bad_targets = [data_filtered[(data_filtered["dN with Chimpanzee"] < quantile_95_dN) & (data_filtered["present in DrugBank"] == False)].shape[0], 
               data_filtered[(data_filtered["dN with Chimpanzee"] >= quantile_95_dN) & (data_filtered["present in DrugBank"] == False)].shape[0]]
good_targets = [data_filtered[(data_filtered["dN with Chimpanzee"] < quantile_95_dN) & (data_filtered["present in DrugBank"] == True)].shape[0], 
               data_filtered[(data_filtered["dN with Chimpanzee"] >= quantile_95_dN) & (data_filtered["present in DrugBank"] == True)].shape[0]]

print('-----------------------------------')
print('Results of Chi2 test for Chimpanzee')
print('-----------------------------------')
print('The contingency table looks like that:')
print(pd.DataFrame([bad_targets, good_targets],
                  index=['bad targets', 'good targets'],
                  columns=['dN < 95% quantile', 'dN ≥ 95% quantile']))
print()
print('95% quantile of dN dist is {}'.format(quantile_95_dN))
chi2_test([bad_targets, good_targets])
print()
# Out:
# -----------------------------------
# Results of Chi2 test for Chimpanzee
# -----------------------------------
# The contingency table looks like that:
#               dN < 95% quantile  dN ≥ 95% quantile
# bad targets                9905                526
# good targets               1381                 70
#
# 95% quantile of dN dist is 0.0425
# significance=0.05, p=0.7695752968617161
# dN & "goodness as a target" are independent

# %%
# for mouse vs human
quantile_95_dN = np.quantile(data_filtered["dN with Mouse"], 0.95)
quantile_95_out=np.quantile(data_filtered[(data_filtered["present in DrugBank"] == False)]["dN with Mouse"], 0.95)
quantile_95_in=np.quantile(data_filtered[(data_filtered["present in DrugBank"] == True)]["dN with Mouse"], 0.95)

sns.set(style="white", font_scale=1.3)
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(14, 6),)

sns.distplot(data_filtered[data_filtered["dN with Mouse"] < 0.5]["dN with Mouse"] , color="#010101", kde=True, ax=ax1)

sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == False) & (data_filtered["dN with Mouse"] < 0.5)]["dN with Mouse"] , color="#f03b20", shade=True, label="not in drugbank", ax=ax2)
sns.kdeplot(data_filtered[(data_filtered["present in DrugBank"] == True) & (data_filtered["dN with Mouse"] < 0.5)]["dN with Mouse"] , color="#756bb1", shade=True, label="in drugbank", ax=ax2)

ax1.axvline(quantile_95_dN, 0, 0.056, color="#000000").set_linestyle("-")
ax2.axvline(quantile_95_in, 0, 0.09, color="#756bb1").set_linestyle("-")
ax2.axvline(quantile_95_out, 0, 0.05, color="#f03b20").set_linestyle("-")

ax2.legend(loc="upper right")

ax1.set_title('dN distribution, all genes, Mouse (all)')
ax2.set_title('dN distribution, by target groups, Mouse (all)')
ax1.set_xlabel('')
ax2.set_xlabel("dN")
ax1.set_ylabel('density')
ax2.set_ylabel('density')

plt.xlim(0,0.5)
plt.show();

bad_targets = [data_filtered[(data_filtered["dN with Mouse"] < quantile_95_dN) & (data_filtered["present in DrugBank"] == False)].shape[0], 
               data_filtered[(data_filtered["dN with Mouse"] >= quantile_95_dN) & (data_filtered["present in DrugBank"] == False)].shape[0]]
good_targets = [data_filtered[(data_filtered["dN with Mouse"] < quantile_95_dN) & (data_filtered["present in DrugBank"] == True)].shape[0], 
               data_filtered[(data_filtered["dN with Mouse"] >= quantile_95_dN) & (data_filtered["present in DrugBank"] == True)].shape[0]]

print('------------------------------')
print('Results of Chi2 test for Mouse')
print('------------------------------')
print('The contingency table looks like that:')
print(pd.DataFrame([bad_targets, good_targets],
                  index=['bad targets', 'good targets'],
                  columns=['dN < 95% quantile', 'dN ≥ 95% quantile']))
print()
print('95% quantile of dN dist is {}'.format(quantile_95_dN))
chi2_test([bad_targets, good_targets])
# Out:
# ------------------------------
# Results of Chi2 test for Mouse
# ------------------------------
# The contingency table looks like that:
#               dN < 95% quantile  dN ≥ 95% quantile
# bad targets                9865                566
# good targets               1422                 29
#
# 95% quantile of dN dist is 0.30378999999999984
# significance=0.05, p=2.9462337596031586e-08
# dN & "goodness as a target" are dependent
